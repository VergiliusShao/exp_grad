# %%
import numpy as np
import matplotlib.pyplot as plt
import os
print(os.getcwd())
# Out:
# /mnt/d/Projects/optimisationpy

# %%
file = open("logistic_AdaGrad.csv")
reg_adagrad = np.loadtxt(file, delimiter=",")
file = open("logistic_AdaFTRL.csv")
reg_adaftrl = np.loadtxt(file, delimiter=",")
file = open("logistic_AdaHU.csv")
reg_adahu = np.loadtxt(file, delimiter=",")
file = open("logistic_AdaExpGrad.csv")
reg_adaexpgrad = np.loadtxt(file, delimiter=",")
file = open("logistic_AdaExpFTRL.csv")
reg_adaexpftrl = np.loadtxt(file, delimiter=",")

# %%
plt.plot(range(0,10000), reg_adagrad,label='AdaGrad', marker='v',markevery=1000)
plt.plot(range(0,10000), reg_adaftrl,label='AdaFTRL', marker='^',markevery=1000)
plt.plot(range(0,10000), reg_adahu,label='HU', marker='s',markevery=1000)
plt.plot(range(0,10000), reg_adaexpgrad,label='Exp-MD', marker='o',markevery=1000)
plt.plot(range(0,10000), reg_adaexpftrl,label='Exp-FTRL', marker='D',markevery=1000)
plt.legend()
plt.xlabel("Iteration")
plt.ylabel("Regret")

# %%
file = open("logistic_AdaGrad_matrix.csv")
reg_adagrad = np.loadtxt(file, delimiter=",")
file = open("logistic_AdaFTRL_matrix.csv")
reg_adaftrl = np.loadtxt(file, delimiter=",")
file = open("logistic_AdaHU_matrix.csv")
reg_adahu = np.loadtxt(file, delimiter=",")
file = open("logistic_AdaExpGrad_matrix.csv")
reg_adaexpgrad = np.loadtxt(file, delimiter=",")
file = open("logistic_AdaExpFTRL_matrix.csv")
reg_adaexpftrl = np.loadtxt(file, delimiter=",")
plt.plot(range(0,10000), reg_adagrad,label='AdaGrad', marker='v',markevery=1000)
plt.plot(range(0,10000), reg_adaftrl,label='AdaFTRL', marker='^',markevery=1000)
plt.plot(range(0,10000), reg_adahu,label='HU', marker='s',markevery=1000)
plt.plot(range(0,10000), reg_adaexpgrad,label='Exp-MD', marker='o',markevery=1000)
plt.plot(range(0,10000), reg_adaexpftrl,label='Exp-FTRL', marker='D',markevery=1000)
plt.legend()
plt.xlabel("Iteration")
plt.ylabel("Regret")

# %%
file = open("experiment_results/CIFER_PN_solvers.ao_grad_True/average_loss.csv")
reg_adagrad = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PN_solvers.ao_ftrl_True/average_loss.csv")
reg_adaftrl = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PN_solvers.ao_exp_grad_True/average_loss.csv")
reg_adaexpgrad = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PN_solvers.ao_exp_ftrl_True/average_loss.csv")
reg_adaexpftrl = np.loadtxt(file, delimiter=",")

# %%
fig, ax=plt.subplots()
ax.plot(range(0,1001), reg_adagrad,label='AccAOMD', marker='v',markevery=100)
ax.plot(range(0,1001), reg_adaftrl,label='AccAOFTRL', marker='^',markevery=100)
ax.plot(range(0,1001), reg_adaexpgrad,label='AccAOExpMD', marker='o',markevery=100)
ax.plot(range(0,1001), reg_adaexpftrl,label='AccAOExpFTRL', marker='D',markevery=100)
plt.xlabel("Iteration")
plt.ylabel("loss")
ax.set_yscale("log")
plt.legend()
plt.show()

# %%
file = open("experiment_results/CIFER_PP_solvers.ao_grad_True/average_loss.csv")
reg_adagrad = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PP_solvers.ao_ftrl_True/average_loss.csv")
reg_adaftrl = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PP_solvers.ao_exp_grad_True/average_loss.csv")
reg_adaexpgrad = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PP_solvers.ao_exp_ftrl_True/average_loss.csv")
reg_adaexpftrl = np.loadtxt(file, delimiter=",")

# %%
fig, ax=plt.subplots()
ax.plot(range(0,1001), reg_adagrad,label='AccAOMD', marker='v',markevery=100)
ax.plot(range(0,1001), reg_adaftrl,label='AccAOFTRL', marker='^',markevery=100)
ax.plot(range(0,1001), reg_adaexpgrad,label='AccAOExpMD', marker='o',markevery=100)
ax.plot(range(0,1001), reg_adaexpftrl,label='AccAOExpFTRL', marker='D',markevery=100)
plt.xlabel("Iteration")
plt.ylabel("loss")
ax.set_yscale("log")
plt.legend()
plt.show()

# %%
file = open("experiment_results/CIFER_PN_solvers.ao_grad_False/average_loss.csv")
reg_adagrad = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PN_solvers.ao_ftrl_False/average_loss.csv")
reg_adaftrl = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PN_solvers.ao_exp_grad_False/average_loss.csv")
reg_adaexpgrad = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PN_solvers.ao_exp_ftrl_False/average_loss.csv")
reg_adaexpftrl = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PN_solvers.fista_False/average_loss.csv")
fista = np.loadtxt(file, delimiter=",")

# %%
fig, ax=plt.subplots()
ax.plot(range(0,1001), reg_adagrad,label='AccAOMD', marker='v',markevery=100)
ax.plot(range(0,1001), reg_adaftrl,label='AccAOFTRL', marker='^',markevery=100)
ax.plot(range(0,1001), fista,label='Fista', marker='s',markevery=100)
ax.plot(range(0,1001), reg_adaexpgrad,label='AccAOExpMD', marker='o',markevery=100)
ax.plot(range(0,1001), reg_adaexpftrl,label='AccAOExpFTRL', marker='D',markevery=100)
plt.xlabel("Iteration")
plt.ylabel("loss")
ax.set_yscale("log")
plt.legend()
plt.show()

# %%
file = open("experiment_results/CIFER_PP_solvers.ao_grad_False/average_loss.csv")
reg_adagrad = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PP_solvers.ao_ftrl_False/average_loss.csv")
reg_adaftrl = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PP_solvers.ao_exp_grad_False/average_loss.csv")
reg_adaexpgrad = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PP_solvers.ao_exp_ftrl_False/average_loss.csv")
reg_adaexpftrl = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PP_solvers.fista_False/average_loss.csv")
fista = np.loadtxt(file, delimiter=",")

# %%
fig, ax=plt.subplots()
ax.plot(range(0,1001), reg_adagrad,label='AccAOMD', marker='v',markevery=100)
ax.plot(range(0,1001), reg_adaftrl,label='AccAOFTRL', marker='^',markevery=100)
ax.plot(range(0,1001), fista,label='Fista', marker='s',markevery=100)
ax.plot(range(0,1001), reg_adaexpgrad,label='AccAOExpMD', marker='o',markevery=100)
ax.plot(range(0,1001), reg_adaexpftrl,label='AccAOExpFTRL', marker='D',markevery=100)
plt.xlabel("Iteration")
plt.ylabel("loss")
ax.set_yscale("log")
plt.legend()
plt.show()

# %%
file = open("experiment_results/CIFER_PN_solvers.spectral.ao_grad_False/average_loss.csv")
reg_adagrad = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PN_solvers.spectral.ao_ftrl_False/average_loss.csv")
reg_adaftrl = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PN_solvers.spectral.ao_exp_grad_False/average_loss.csv")
reg_adaexpgrad = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PN_solvers.spectral.ao_exp_ftrl_False/average_loss.csv")
reg_adaexpftrl = np.loadtxt(file, delimiter=",")

# %%
fig, ax=plt.subplots()
ax.plot(range(0,1001), reg_adagrad,label='AccAOMD', marker='v',markevery=100)
ax.plot(range(0,1001), reg_adaftrl,label='AccAOFTRL', marker='^',markevery=100)
ax.plot(range(0,1001), reg_adaexpgrad,label='AccAOExpMD', marker='o',markevery=100)
ax.plot(range(0,1001), reg_adaexpftrl,label='AccAOExpFTRL', marker='D',markevery=100)
plt.xlabel("Iteration")
plt.ylabel("loss")
ax.set_yscale("log")
plt.legend()
plt.show()

# %%
file = open("experiment_results/CIFER_PP_solvers.spectral.ao_grad_False/average_loss.csv")
reg_adagrad = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PP_solvers.spectral.ao_ftrl_False/average_loss.csv")
reg_adaftrl = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PP_solvers.spectral.ao_exp_grad_False/average_loss.csv")
reg_adaexpgrad = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PP_solvers.spectral.ao_exp_ftrl_False/average_loss.csv")
reg_adaexpftrl = np.loadtxt(file, delimiter=",")

# %%
fig, ax=plt.subplots()
ax.plot(range(0,1001), reg_adagrad,label='AccAOMD', marker='v',markevery=100)
ax.plot(range(0,1001), reg_adaftrl,label='AccAOFTRL', marker='^',markevery=100)
ax.plot(range(0,1001), reg_adaexpgrad,label='AccAOExpMD', marker='o',markevery=100)
ax.plot(range(0,1001), reg_adaexpftrl,label='AccAOExpFTRL', marker='D',markevery=100)
plt.xlabel("Iteration")
plt.ylabel("loss")
ax.set_yscale("log")
plt.legend()
plt.show()

# %%
file = open("experiment_results/CIFER_PN_solvers.spectral.ao_grad_True/average_loss.csv")
reg_adagrad = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PN_solvers.spectral.ao_ftrl_True/average_loss.csv")
reg_adaftrl = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PN_solvers.spectral.ao_exp_grad_True/average_loss.csv")
reg_adaexpgrad = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PN_solvers.spectral.ao_exp_ftrl_True/average_loss.csv")
reg_adaexpftrl = np.loadtxt(file, delimiter=",")

# %%
fig, ax=plt.subplots()
ax.plot(range(0,1001), reg_adagrad,label='AdaMD', marker='v',markevery=100)
ax.plot(range(0,1001), reg_adaftrl,label='AdaFTRL', marker='^',markevery=100)
ax.plot(range(0,1001), reg_adaexpgrad,label='AdaExpMD', marker='s',markevery=100)
ax.plot(range(0,1001), reg_adaexpftrl,label='AdaExpFTRL', marker='o',markevery=100)
plt.xlabel("Iteration")
plt.ylabel("loss")
ax.set_yscale("log")
plt.legend()
plt.show()

# %%
file = open("experiment_results/CIFER_PP_solvers.spectral.ao_grad_True/average_loss.csv")
reg_adagrad = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PP_solvers.spectral.ao_ftrl_True/average_loss.csv")
reg_adaftrl = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PP_solvers.spectral.ao_exp_grad_True/average_loss.csv")
reg_adaexpgrad = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PP_solvers.spectral.ao_exp_ftrl_True/average_loss.csv")
reg_adaexpftrl = np.loadtxt(file, delimiter=",")

# %%
fig, ax=plt.subplots()
ax.plot(range(0,1001), reg_adagrad,label='AccAOMD', marker='v',markevery=100)
ax.plot(range(0,1001), reg_adaftrl,label='AccAOFTRL', marker='^',markevery=100)
ax.plot(range(0,1001), reg_adaexpgrad,label='AccAOExpMD', marker='o',markevery=100)
ax.plot(range(0,1001), reg_adaexpftrl,label='AccAOExpFTRL', marker='D',markevery=100)
plt.xlabel("Iteration")
plt.ylabel("loss")
ax.set_yscale("log")
plt.legend()
plt.show()

# %%
file = open("experiment_results/CIFER_PP_solvers.ao_exp_grad_False/average_loss.csv")
grad = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PP_solvers.ao_exp_ftrl_False/average_loss.csv")
ftrl = np.loadtxt(file, delimiter=",")
file = open("experiment_results/CIFER_PP_solvers.fista_False/average_loss.csv")
fista = np.loadtxt(file, delimiter=",")

# %%
fig, ax=plt.subplots()
ax.plot(range(0,1001), grad,label='grad', marker='v',markevery=100)
ax.plot(range(0,1001),ftrl,label='ftrl', marker='s',markevery=100)
ax.plot(range(0,1001), fista,label='fista', marker='^',markevery=100)
plt.xlabel("Iteration")
plt.ylabel("loss")
ax.set_yscale("log")
plt.legend()
plt.show()
